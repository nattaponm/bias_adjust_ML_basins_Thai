# %% [markdown]
# # โค้ดสร้าง cappi หลายระดับความสูง ประมวลผลไฟล์ต่อไฟล์

# %% [markdown]
# * ToA 15000 SNR 1dB ไม่เอาค่า above
# * mean dBZ แทน max dBZ
# * ยกเลิก roi_func='constant', constant_roi=4000.0 #ไม่เลือกตรงนี้ เพราะให้โปรแกรมสร้าง effective radius ตามขนาดลำบีมที่ขยายตามระยะทาง

# %%
import os
import numpy as np
import xarray as xr
import rioxarray
import pyart
from datetime import datetime
from dateutil import tz
import copy  # Add this import for the copy module
import warnings
warnings.filterwarnings("ignore")
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
# <frozen importlib._bootstrap>:283: DeprecationWarning: the load_module() method is deprecated and slated for removal in Python 3.12; use exec_module() instead

# %%
def utc2local_hr(time_rad):
    from_zone = tz.tzutc()
    to_zone = tz.tzlocal()
    utc = datetime.strptime(time_rad, "%Y%m%d%H")
    utc = utc.replace(tzinfo=from_zone)
    lst = utc.astimezone(to_zone)
    return lst

def snr_atten_cor(radar):
    snr = pyart.retrieve.calculate_snr_from_reflectivity(radar, refl_field='reflectivity', toa=15000.0)
    radar.add_field('signal_to_noise_ratio', snr, replace_existing=True)
    gtfilter = pyart.filters.moment_and_texture_based_gate_filter(radar, phi_field='differential_phase')
    gtfilter.exclude_below('signal_to_noise_ratio', 1) # จาก 5 dB เป็น 1 dB
    #gtfilter.exclude_above('signal_to_noise_ratio', 70) # ไม่เอาค่านี้
    radar.add_field_like('reflectivity', 'reflectivity_copy', radar.fields['reflectivity']['data'].copy())
    nf = radar.fields['reflectivity_copy']
    nf['data'] = np.ma.masked_where(gtfilter.gate_excluded, nf['data'])
    radar.add_field('filtered_reflectivity', nf, replace_existing=True)

    ncp_values = np.ones((radar.nrays, radar.ngates))
    ncp = pyart.config.get_metadata('normalized_coherent_power')
    ncp['data'] = ncp_values
    radar.add_field('normalized_coherent_power', ncp)

    phidp, kdp = pyart.correct.phase_proc_lp(radar, 0.0, LP_solver='pyglpk', debug=True)
    radar.add_field('proc_dp_phase_shift', phidp)
    radar.add_field('recalculated_diff_phase', kdp)

    spec_at, cor_z = pyart.correct.calculate_attenuation(
        radar,
        0,
        fzl=4500.0,
        refl_field="filtered_reflectivity",
        ncp_field="normalized_coherent_power",
        rhv_field="cross_correlation_ratio",
        phidp_field="proc_dp_phase_shift",
    )
    radar.add_field("specific_attenuation", spec_at)
    radar.add_field("corrected_filtered_reflectivity", cor_z)

    return radar

def gridding_cappi_convert_grid2xarray(radar, height):
    lat_0 = radar.latitude['data'][0]
    lon_0 = radar.longitude['data'][0]

    shape = (11, 241, 241)
    grid = pyart.map.grid_from_radars(
        radar,
        grid_shape=shape,
        grid_limits=((0, 10000), (-240000, 240000), (-240000, 240000)),
        grid_origin=(lat_0, lon_0),
        fields=['corrected_filtered_reflectivity']#,
        #roi_func='constant', constant_roi=4000.0 #ไม่เลือกตรงนี้ เพราะให้โปรแกรมสร้าง effective radius ตามขนาดลำบีมที่ขยายตามระยะทาง
    )

    ds = grid.to_xarray()
    grid_data = ds['corrected_filtered_reflectivity'][0, height, :, :]

    return grid_data

def save_geotif(cappi_max_hr, path_outfile):
    cappi_max_hr = cappi_max_hr.to_dataset().squeeze().set_index(x="lon", y="lat")
    cappi_max_hr.rio.set_spatial_dims(x_dim='x', y_dim='y', inplace=True)
    cappi_max_hr.rio.set_crs("EPSG:4326")
    cappi_max_hr.rio.write_crs("EPSG:4326", inplace=True)
    cappi_max_hr.rio.write_transform()
    cappi_max_hr.rio.write_coordinate_system()
    cappi_max_hr.rio.to_raster(path_outfile)
    cappi_max_hr.close()

# %%
def main():
    dir_path = 'D:/1Yang/0Geoinformatic_data/0radar_data/phs_2018_events/0combined_4events_1234/'
    #dir_path = 'D:/1Yang/0Geoinformatic_data/0radar_data/phs_2018_events/ztest/'
    path_results = '../00Results/00outp_cappi_ppi_hourly_phs2018_mean_dBZ/0train_val_models/cappi/'
    #path_results = './00Results/0outp_cappi_ppi_hourly/ztmp/cappi/'

    fn_all = [file for file in os.listdir(dir_path) if file.endswith('.uf.bz2')]
    fn_hr = list(np.unique([file[7:-9] for file in fn_all]))
    #fn_hr = list(np.unique([file[3:-5] for file in fn_all]))

    # Read and preprocess radar data for SNR and attenuation correction
    radar_dict = {}
    
    for sub_file_hr in fn_hr:
        files_15min = [file for file in fn_all if sub_file_hr in file]
        
        if len(files_15min)!= 4 : 
            print('!!! skip! ', sub_file_hr, ' < ', 4) # ถ้าจำนวนไฟล์ไม่ถึง 4 ไฟล์/ชั่วโมง ให้ตัดออกไป
            continue
        
        # Initialize radar_list to store radar data for all files in the current hour
        radar_list = []
        
        print('#---> processing '+sub_file_hr+' ...>>>')
        print('#1.> ปรับแก้ SNR and attenuation correction...')
        for file_15min in files_15min:
            
            try:
                
                radar = pyart.io.read(os.path.join(dir_path, file_15min))
                radar.metadata['file_name'] = file_15min  # Store file name as metadata เก็บไว้เพื่อ print
                radar = snr_atten_cor(radar)
                radar_list.append(radar)
            
            except Exception as e:
                print(f"Error processing {file_15min}: {e}")
                continue

        # Add the list of corrected radar data to the dictionary with the hour as the key
        radar_dict[sub_file_hr] = radar_list

        #break
        
        # Specify the heights you want to generate CAPPI for
        heights = [1, 2, 3, 4]
        print('#2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....')
        for height in heights:
            #for sub_file_hr, radar_list in radar_dict.items(): 
            local_time = utc2local_hr(sub_file_hr).strftime('%Y%m%d%H')
            print('---------------------------------------\n')
            print('Find max for .......>>>', sub_file_hr)
            con_xr = []

            for radar in radar_list: 
                #print(f'Doing ...>>> {radar.metadata}') #file_15min อันนี้ไม่เวิร์คนะ ชื่อไม่ตรงกับที่ประมวลผล ต้องลองสัก 2 ชั่วโมงดู
                print('.......>>>', radar.metadata['file_name'])

                # Reuse the corrected radar data for different heights
                radar_copy = copy.deepcopy(radar)  # Use deepcopy instead of copy

                print(f'>> Do gridding CAPPI at height {height} km...')
                grid = gridding_cappi_convert_grid2xarray(radar_copy, height)
                con_xr.append(grid)

            print(f'+ Do find max of CAPPI at {height} km...')
            cappi_con_xr = xr.concat(con_xr, dim='time')
            cappi_max_hr = cappi_con_xr.mean(dim='time') # เอา mean แทน
            #cappi_max_hr = cappi_con_xr.max(dim='time') #ไม่เอา max ทดสอบเพราะ max มัน overestimate

            print(f'+ Do save results for CAPPI at {height} km...')

            # Specify the height for folder creation
            height_folder = height
            folder_name = f'cappi{height_folder}km'

            # Create the folder if it doesn't exist
            folder_path = os.path.join(path_results, folder_name)
            os.makedirs(folder_path, exist_ok=True)

            outp_name = local_time + '.tif'
            save_geotif(cappi_max_hr, os.path.join(folder_path, outp_name))
            print(f'---------------Saved results for CAPPI at {height} km---------------\n')

        #break
    
if __name__ == "__main__":
    main()
# Out:
# #---> processing 2018081401 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.0137088298797607
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0001587867736816
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Error processing PHS240@201808140130.uf.bz2: Unknown or unsupported file format: UNKNOWN
# Unfolding
# Exec time:  1.0099492073059082
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081401
# .......>>> PHS240@201808140100.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140115.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140145.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081401
# .......>>> PHS240@201808140100.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140115.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140145.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081401
# .......>>> PHS240@201808140100.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140115.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140145.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081401
# .......>>> PHS240@201808140100.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140115.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140145.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018081402 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.0007283687591553
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  0.9889421463012695
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  0.9982964992523193
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  0.9987874031066895
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081402
# .......>>> PHS240@201808140200.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140215.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140230.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140245.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081402
# .......>>> PHS240@201808140200.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140215.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140230.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140245.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081402
# .......>>> PHS240@201808140200.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140215.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140230.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140245.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081402
# .......>>> PHS240@201808140200.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140215.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140230.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140245.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018081403 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.004838466644287
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  0.9949569702148438
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0109548568725586
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0038681030273438
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081403
# .......>>> PHS240@201808140300.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140315.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140330.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140345.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081403
# .......>>> PHS240@201808140300.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140315.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140330.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140345.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081403
# .......>>> PHS240@201808140300.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140315.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140330.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140345.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081403
# .......>>> PHS240@201808140300.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140315.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140330.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140345.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018081404 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.0063014030456543
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0074784755706787
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  0.9993789196014404
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0092506408691406
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081404
# .......>>> PHS240@201808140400.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140415.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140430.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140445.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081404
# .......>>> PHS240@201808140400.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140415.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140430.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140445.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081404
# .......>>> PHS240@201808140400.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140415.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140430.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140445.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081404
# .......>>> PHS240@201808140400.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140415.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140430.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140445.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018081405 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  0.9993674755096436
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0120689868927002
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  0.9970133304595947
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.008880615234375
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081405
# .......>>> PHS240@201808140500.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140515.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140530.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140545.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081405
# .......>>> PHS240@201808140500.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140515.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140530.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140545.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081405
# .......>>> PHS240@201808140500.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140515.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140530.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140545.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081405
# .......>>> PHS240@201808140500.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140515.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140530.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140545.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018081406 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.0489985942840576
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  0.9426157474517822
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  0.952404260635376
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  0.9559097290039062
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081406
# .......>>> PHS240@201808140600.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140615.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140630.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140645.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081406
# .......>>> PHS240@201808140600.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140615.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140630.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140645.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081406
# .......>>> PHS240@201808140600.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140615.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140630.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140645.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081406
# .......>>> PHS240@201808140600.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140615.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140630.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140645.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018081407 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  0.9613902568817139
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  0.9728515148162842
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  0.9546248912811279
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  0.9714920520782471
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081407
# .......>>> PHS240@201808140700.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140715.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140730.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140745.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081407
# .......>>> PHS240@201808140700.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140715.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140730.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140745.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081407
# .......>>> PHS240@201808140700.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140715.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140730.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140745.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081407
# .......>>> PHS240@201808140700.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140715.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140730.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140745.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018081408 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  0.9866397380828857
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0160348415374756
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0131809711456299
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.020752191543579
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081408
# .......>>> PHS240@201808140800.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140815.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140830.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140845.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081408
# .......>>> PHS240@201808140800.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140815.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140830.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140845.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081408
# .......>>> PHS240@201808140800.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140815.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140830.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140845.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081408
# .......>>> PHS240@201808140800.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140815.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140830.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140845.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018081409 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.0231475830078125
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0082530975341797
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.019188404083252
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.009087324142456
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081409
# .......>>> PHS240@201808140900.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140915.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140930.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808140945.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081409
# .......>>> PHS240@201808140900.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140915.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140930.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808140945.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081409
# .......>>> PHS240@201808140900.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140915.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140930.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808140945.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081409
# .......>>> PHS240@201808140900.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140915.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140930.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808140945.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018081410 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.002289056777954
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0175466537475586
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.012864589691162
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.014164686203003
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081410
# .......>>> PHS240@201808141000.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141015.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141030.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141045.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081410
# .......>>> PHS240@201808141000.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141015.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141030.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141045.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081410
# .......>>> PHS240@201808141000.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141015.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141030.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141045.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081410
# .......>>> PHS240@201808141000.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141015.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141030.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141045.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018081411 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.0117239952087402
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.005448579788208
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.011197805404663
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0166170597076416
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081411
# .......>>> PHS240@201808141100.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141115.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141130.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141145.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081411
# .......>>> PHS240@201808141100.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141115.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141130.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141145.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081411
# .......>>> PHS240@201808141100.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141115.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141130.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141145.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081411
# .......>>> PHS240@201808141100.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141115.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141130.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141145.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018081412 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.0109431743621826
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0172061920166016
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0122854709625244
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0091068744659424
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081412
# .......>>> PHS240@201808141200.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141215.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141230.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141245.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081412
# .......>>> PHS240@201808141200.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141215.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141230.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141245.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081412
# .......>>> PHS240@201808141200.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141215.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141230.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141245.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081412
# .......>>> PHS240@201808141200.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141215.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141230.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141245.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018081413 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.022402286529541
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0243275165557861
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0213396549224854
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0133843421936035
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081413
# .......>>> PHS240@201808141300.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141315.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141330.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141345.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081413
# .......>>> PHS240@201808141300.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141315.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141330.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141345.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081413
# .......>>> PHS240@201808141300.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141315.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141330.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141345.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081413
# .......>>> PHS240@201808141300.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141315.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141330.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141345.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018081414 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.0044817924499512
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  0.9944255352020264
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.005976676940918
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0061945915222168
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081414
# .......>>> PHS240@201808141400.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141415.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141430.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141445.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081414
# .......>>> PHS240@201808141400.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141415.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141430.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141445.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081414
# .......>>> PHS240@201808141400.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141415.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141430.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141445.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081414
# .......>>> PHS240@201808141400.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141415.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141430.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141445.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018081415 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  0.9982714653015137
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0041518211364746
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0022168159484863
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0034327507019043
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081415
# .......>>> PHS240@201808141500.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141515.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141530.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141545.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081415
# .......>>> PHS240@201808141500.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141515.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141530.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141545.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081415
# .......>>> PHS240@201808141500.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141515.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141530.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141545.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081415
# .......>>> PHS240@201808141500.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141515.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141530.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141545.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018081416 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.0069997310638428
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0221025943756104
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0168428421020508
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0319175720214844
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081416
# .......>>> PHS240@201808141600.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141615.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141630.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141645.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081416
# .......>>> PHS240@201808141600.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141615.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141630.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141645.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081416
# .......>>> PHS240@201808141600.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141615.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141630.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141645.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081416
# .......>>> PHS240@201808141600.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141615.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141630.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141645.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018081417 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.003016710281372
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.010840892791748
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0250000953674316
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.007322072982788
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081417
# .......>>> PHS240@201808141700.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141715.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141730.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808141745.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081417
# .......>>> PHS240@201808141700.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141715.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141730.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808141745.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081417
# .......>>> PHS240@201808141700.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141715.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141730.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808141745.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081417
# .......>>> PHS240@201808141700.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141715.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141730.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808141745.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# !!! skip!  2018081418  <  4
# #---> processing 2018081500 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.035630702972412
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.012077808380127
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0186271667480469
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0153522491455078
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081500
# .......>>> PHS240@201808150000.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808150015.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808150030.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808150045.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081500
# .......>>> PHS240@201808150000.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808150015.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808150030.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808150045.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081500
# .......>>> PHS240@201808150000.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808150015.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808150030.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808150045.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081500
# .......>>> PHS240@201808150000.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808150015.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808150030.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808150045.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018081501 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.0076985359191895
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0007121562957764
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  0.9884459972381592
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  0.9842724800109863
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018081501
# .......>>> PHS240@201808150100.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808150115.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808150130.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201808150145.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081501
# .......>>> PHS240@201808150100.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808150115.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808150130.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201808150145.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081501
# .......>>> PHS240@201808150100.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808150115.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808150130.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201808150145.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018081501
# .......>>> PHS240@201808150100.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808150115.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808150130.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201808150145.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# !!! skip!  2018081502  <  4
# #---> processing 2018081503 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  0.9912943840026855
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0175204277038574
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  0.9932479858398438
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  0.999295711517334
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# ...
# .......>>> PHS240@201809210915.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809210930.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809210945.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092109
# .......>>> PHS240@201809210900.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809210915.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809210930.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809210945.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018092110 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.040717363357544
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0263121128082275
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0283286571502686
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0431890487670898
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018092110
# .......>>> PHS240@201809211000.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211015.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211030.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211045.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092110
# .......>>> PHS240@201809211000.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211015.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211030.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211045.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092110
# .......>>> PHS240@201809211000.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211015.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211030.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211045.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092110
# .......>>> PHS240@201809211000.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211015.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211030.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211045.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018092111 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.0399158000946045
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.037480115890503
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.053394079208374
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0268170833587646
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018092111
# .......>>> PHS240@201809211100.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211115.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211130.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211145.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092111
# .......>>> PHS240@201809211100.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211115.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211130.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211145.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092111
# .......>>> PHS240@201809211100.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211115.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211130.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211145.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092111
# .......>>> PHS240@201809211100.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211115.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211130.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211145.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018092112 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.0294263362884521
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0228586196899414
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.017723798751831
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.014573335647583
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018092112
# .......>>> PHS240@201809211200.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211215.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211230.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211245.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092112
# .......>>> PHS240@201809211200.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211215.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211230.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211245.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092112
# .......>>> PHS240@201809211200.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211215.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211230.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211245.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092112
# .......>>> PHS240@201809211200.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211215.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211230.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211245.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018092113 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.0290451049804688
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0365245342254639
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0313410758972168
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.03257417678833
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018092113
# .......>>> PHS240@201809211300.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211315.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211330.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211345.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092113
# .......>>> PHS240@201809211300.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211315.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211330.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211345.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092113
# .......>>> PHS240@201809211300.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211315.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211330.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211345.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092113
# .......>>> PHS240@201809211300.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211315.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211330.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211345.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# #---> processing 2018092114 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.0404243469238281
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0383033752441406
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0537610054016113
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0285038948059082
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018092114
# .......>>> PHS240@201809211400.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211415.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211430.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211445.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092114
# .......>>> PHS240@201809211400.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211415.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211430.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211445.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092114
# .......>>> PHS240@201809211400.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211415.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211430.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211445.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092114
# .......>>> PHS240@201809211400.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211415.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211430.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211445.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
#
# !!! skip!  2018092115  <  4
# #---> processing 2018092116 ...>>>
# #1.> ปรับแก้ SNR and attenuation correction...
# Unfolding
# Exec time:  1.042464256286621
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0325689315795898
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0267181396484375
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# Unfolding
# Exec time:  1.0332987308502197
# Doing  0
# Doing  1
# Doing  2
# Doing  3
# #2.> สร้างแผนที่ CAPPIs ตามระดับความสูง....
# ---------------------------------------
#
# Find max for .......>>> 2018092116
# .......>>> PHS240@201809211600.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211615.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211630.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# .......>>> PHS240@201809211645.uf.bz2
# >> Do gridding CAPPI at height 1 km...
# + Do find max of CAPPI at 1 km...
# + Do save results for CAPPI at 1 km...
# ---------------Saved results for CAPPI at 1 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092116
# .......>>> PHS240@201809211600.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211615.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211630.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# .......>>> PHS240@201809211645.uf.bz2
# >> Do gridding CAPPI at height 2 km...
# + Do find max of CAPPI at 2 km...
# + Do save results for CAPPI at 2 km...
# ---------------Saved results for CAPPI at 2 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092116
# .......>>> PHS240@201809211600.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211615.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211630.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# .......>>> PHS240@201809211645.uf.bz2
# >> Do gridding CAPPI at height 3 km...
# + Do find max of CAPPI at 3 km...
# + Do save results for CAPPI at 3 km...
# ---------------Saved results for CAPPI at 3 km---------------
#
# ---------------------------------------
#
# Find max for .......>>> 2018092116
# .......>>> PHS240@201809211600.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211615.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211630.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# .......>>> PHS240@201809211645.uf.bz2
# >> Do gridding CAPPI at height 4 km...
# + Do find max of CAPPI at 4 km...
# + Do save results for CAPPI at 4 km...
# ---------------Saved results for CAPPI at 4 km---------------
